# %% [markdown]
# # Train Test Split
# This notebook contains functionality to split the images into a train and test set and to create an annotation csv-file used by the pytorch data loader.

# %%
import random
import re
import sys

import numpy as np
import pandas as pd

sys.path.insert(0, '../../scripts/')

from helpers import miscellaneous as misc

CONFIG = misc.get_config()

# %% [markdown]
# ## Split with label CN, MCI and AD

# %%
# load image descriptions
df = pd.read_csv('../../' + CONFIG['RAW_DATA_DIR'] + 'images/ADNI1_Complete_1Yr_1.5T_1_20_2022.csv')
df.head()
# Out:
#   Image Data ID     Subject Group Sex  Age  Visit Modality  \
# 0        I97327  941_S_1311   MCI   M   69      1      MRI
# 1       I112538  941_S_1311   MCI   M   70      4      MRI
# 2        I97341  941_S_1311   MCI   M   70      3      MRI
# 3        I63874  941_S_1202    CN   M   78      1      MRI
# 4        I75150  941_S_1202    CN   M   78      3      MRI
#
#                                   Description       Type   Acq Date Format  \
# 0    MPR; GradWarp; B1 Correction; N3; Scaled  Processed  3/02/2007  NiFTI
# 1    MPR; GradWarp; B1 Correction; N3; Scaled  Processed  6/01/2008  NiFTI
# 2  MPR-R; GradWarp; B1 Correction; N3; Scaled  Processed  9/27/2007  NiFTI
# 3  MPR-R; GradWarp; B1 Correction; N3; Scaled  Processed  1/30/2007  NiFTI
# 4    MPR; GradWarp; B1 Correction; N3; Scaled  Processed  8/24/2007  NiFTI
#
#    Downloaded
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
example_file_name = 'ADNI_002_S_1155_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20070217034919863_S24144_I40845.nii'

regex_pattern = '(I[0-9]*)\.nii'  # extracts image data id from file name

re.findall(regex_pattern, example_file_name)
# Out:
# ['I40845']

# %%
re.search('I40845', example_file_name)
# Out:
# <re.Match object; span=(88, 94), match='I40845'>

# %%
nii_files = misc.get_nii_filenames(CONFIG['FLATTENED_DATA_DIR'])
nii_files[:2]
CONFIG
# Out:
# {'RAW_DATA_DIR': 'data/raw/',
#  'PROCESSED_DATA_DIR': 'data/processed/',
#  'FLATTENED_DATA_DIR': 'data/raw/flattened/',
#  'SERIALIZED_MODELS': 'models/trained_models/',
#  'METRICS_DIR': 'models/trained_history/',
#  'ANNOTATIONS_DIR': 'data/annotations/',
#  'CDR_DIR': 'data/tabular_data/tabular_data/CDR.csv',
#  'GDSCALE_DIR': 'data/tabular_data/tabular_data/GDSCALE.csv',
#  'MMSE_DIR': 'data/tabular_data/tabular_data/MMSE.csv',
#  'MOCA_DIR': 'data/tabular_data/tabular_data/MOCA.csv',
#  'NEUROBAT_DIR': 'data/tabular_data/tabular_data/NEUROBAT.csv',
#  'PTDEMOG_DIR': 'data/tabular_data/tabular_data/PTDEMOG.csv',
#  'DEVICE': 'cuda',
#  'COLOR_SEQUENTIAL': 'bone',
#  'COLOR_DISCRETE': 'Paired',
#  'RANDOM_STATE': '42'}

# %%
def split_into_train_test(df, group_identifier, cognitive_test_path = None, proportion=0.8, save_files=False):
    """
    df: file to ADNI images dataset
    group_identifier: identifier for CN, MCI or AD
    cognitive_test_path: if not none: add to each image a cognitive test result based on the given test, default: None
    proportion: train/test split proportion, default: 0.8
    save_files: save as file (True/False), default: False
    """
    assert 1 > proportion > 0, f'parameter proportion has to be in range [0,1]. {proportion} was given'

    testset = pd.DataFrame(columns=['filename', 'Group', 'Subject'])
    trainset = pd.DataFrame(columns=['filename', 'Group', 'Subject'])

    # df_files = map_imageID_to_file(df, misc.get_nii_filenames(CONFIG['FLATTENED_DATA_DIR']))

    # add filenames to df
    filenames = misc.get_nii_filenames(CONFIG['FLATTENED_DATA_DIR'])

    def get_filename_by_id(x):
        filename = [file for file in filenames if x['Image Data ID'] in file]
        if len(filename) == 1:
            return filename[0]
    #   else:
    #       print(x['Image Data ID']) # fixme missing images?

    df['filename'] = df.apply(get_filename_by_id, axis=1)

    # group by identifier
    df_grouped = df.groupby(group_identifier)

    groups = df[group_identifier].unique()
    for group in groups:
        df_group = df_grouped.get_group(group)
        subjects = df_group['Subject'].unique()
        random.seed(CONFIG['RANDOM_STATE'])
        random.shuffle(subjects)

        n_train = int(len(subjects) * proportion)  # accordingly n_test = len(subjects) - n_train

        train_subjects = subjects[:n_train]
        test_subjects = subjects[n_train:]

        sub_trainset = df_group[df_group['Subject'].isin(train_subjects)]
        sub_testset = df_group[df_group['Subject'].isin(test_subjects)]
        
        trainset_cognitive_test_column_list = []
        testset_cognitive_test_column_list = []
        
        if(cognitive_test_path is not None):
            sub_trainset, trainset_cognitive_test_column_list = get_cognitive_test_set(sub_trainset, cognitive_test_path)
            sub_testset, testset_cognitive_test_column_list = get_cognitive_test_set(sub_testset, cognitive_test_path)
        
        trainset = pd.concat([trainset, sub_trainset[['filename', 'Group', 'Subject'] + trainset_cognitive_test_column_list]], ignore_index=True)
        testset = pd.concat([testset, sub_testset[['filename', 'Group', 'Subject'] + testset_cognitive_test_column_list]], ignore_index=True)
        
        
    if save_files:
        trainset.to_csv('../../' + CONFIG['ANNOTATIONS_DIR'] + 'train_labels.csv', sep=',', header=True, index=False)
        testset.to_csv('../../' + CONFIG['ANNOTATIONS_DIR'] + 'test_labels.csv', sep=',', header=True, index=False)

        return None

    return trainset, testset

def get_cognitive_test_set(subjects, path_to_cognitive_test_set):
    """
    Merges the train or test set entries with their cognitive test result data by looking at the date of the USERDATE attribute.
    Mathces image date of acquisition to the closest cognitive test result in time.
    TODO: see if USERDATE is adequate to match with "acq date" attribute from the images.
    """
    subjects["Subject_ID"] = subjects["Subject"].apply(lambda x: x.split("_")[-1])
    subjects["Acq Date"] = pd.to_datetime(subjects["Acq Date"])

    cognitive_test_results = pd.read_csv(path_to_cognitive_test_set)

    cognitive_test_results.USERDATE = pd.to_datetime(cognitive_test_results.USERDATE)

    #fill dictionary with all the test results by matching subject_id with RID
    dicts = {}
    for item in subjects["Subject_ID"].unique(): dicts[item]=cognitive_test_results[cognitive_test_results.RID == int(item)]

    #this could potentially replace all of the active code below
    """subjects[cognitive_test_results.columns] = np.nan
    for i in range(0, len(subjects)):
        value = get_closest_test_result_by_date(subjects.iloc[i], dicts)
        subjects.loc[i, cognitive_test_results.columns.values.tolist()] = value"""
    
    closest_test_results = [get_closest_test_result_by_date(subjects.iloc[i], dicts) for i in range(0, len(subjects))]
    closest_test_results = pd.concat(closest_test_results).reset_index(drop=True)
    subjects = subjects.reset_index(drop=True)
    subjects_ = pd.concat([subjects, closest_test_results], axis=1)
    return subjects_, cognitive_test_results.columns.values.tolist()

def get_closest_test_result_by_date(item, dicts):
    #Needs check when it doesn't find anything in the list of all cognitive test results
    try:
        test_results = dicts[item.Subject_ID]
        test_results = test_results[test_results.USERDATE ==  min(test_results.USERDATE, key = lambda x: abs(x - item["Acq Date"]))]
        return(test_results)
    except:
        print(f"test_result not found for image subject ID {item.Subject_ID}, returning NONE")
        #Implement if needed
        value = next(iter(dicts.values()))
        value = pd.DataFrame(columns = value.columns)
        value = value.append([np.nan], ignore_index=True)
        return(value)

split_into_train_test(df, 'Group', cognitive_test_path = '../../'  + CONFIG['MOCA_DIR'], save_files=True)
# Out:
# C:\Users\bruno\AppData\Local\Temp/ipykernel_17516/1815732370.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subjects["Subject_ID"] = subjects["Subject"].apply(lambda x: x.split("_")[-1])
# C:\Users\bruno\AppData\Local\Temp/ipykernel_17516/1815732370.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subjects["Acq Date"] = pd.to_datetime(subjects["Acq Date"])
# test_result not found for image subject ID 1311, returning NONE
# test_result not found for image subject ID 1311, returning NONE
# test_result not found for image subject ID 1311, returning NONE
# test_result not found for image subject ID 1245, returning NONE
# test_result not found for image subject ID 1245, returning NONE
# test_result not found for image subject ID 1245, returning NONE
# test_result not found for image subject ID 0982, returning NONE
# test_result not found for image subject ID 0982, returning NONE
# test_result not found for image subject ID 0982, returning NONE
# test_result not found for image subject ID 1426, returning NONE
# test_result not found for image subject ID 1426, returning NONE
# test_result not found for image subject ID 1426, returning NONE
# test_result not found for image subject ID 0825, returning NONE
# test_result not found for image subject ID 0825, returning NONE
# test_result not found for image subject ID 0825, returning NONE
# test_result not found for image subject ID 0669, returning NONE
# test_result not found for image subject ID 0669, returning NONE
# test_result not found for image subject ID 0669, returning NONE
# test_result not found for image subject ID 0631, returning NONE
# test_result not found for image subject ID 0631, returning NONE
# test_result not found for image subject ID 0631, returning NONE
# test_result not found for image subject ID 0481, returning NONE
# test_result not found for image subject ID 0481, returning NONE
# test_result not found for image subject ID 0481, returning NONE
# test_result not found for image subject ID 0443, returning NONE
# test_result not found for image subject ID 0443, returning NONE
# test_result not found for image subject ID 0443, returning NONE
# test_result not found for image subject ID 0158, returning NONE
# test_result not found for image subject ID 0158, returning NONE
# test_result not found for image subject ID 0158, returning NONE
# test_result not found for image subject ID 0874, returning NONE
# test_result not found for image subject ID 0874, returning NONE
# test_result not found for image subject ID 0874, returning NONE
# test_result not found for image subject ID 0579, returning NONE
# test_result not found for image subject ID 0579, returning NONE
# test_result not found for image subject ID 0579, returning NONE
# test_result not found for image subject ID 0579, returning NONE
# test_result not found for image subject ID 0429, returning NONE
# test_result not found for image subject ID 0429, returning NONE
# test_result not found for image subject ID 0429, returning NONE
# test_result not found for image subject ID 0429, returning NONE
# test_result not found for image subject ID 0913, returning NONE
# test_result not found for image subject ID 0913, returning NONE
# test_result not found for image subject ID 0913, returning NONE
# test_result not found for image subject ID 0913, returning NONE
# test_result not found for image subject ID 0913, returning NONE
# test_result not found for image subject ID 0222, returning NONE
# test_result not found for image subject ID 1070, returning NONE
# test_result not found for image subject ID 1070, returning NONE
# test_result not found for image subject ID 1070, returning NONE
# test_result not found for image subject ID 0782, returning NONE
# test_result not found for image subject ID 0782, returning NONE
# test_result not found for image subject ID 0782, returning NONE
# test_result not found for image subject ID 0782, returning NONE
# C:\Users\bruno\AppData\Local\Temp/ipykernel_17516/1815732370.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subjects["Subject_ID"] = subjects["Subject"].apply(lambda x: x.split("_")[-1])
# C:\Users\bruno\AppData\Local\Temp/ipykernel_17516/1815732370.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subjects["Acq Date"] = pd.to_datetime(subjects["Acq Date"])
# test_result not found for image subject ID 0851, returning NONE
# test_result not found for image subject ID 0851, returning NONE
# test_result not found for image subject ID 0851, returning NONE
# test_result not found for image subject ID 1227, returning NONE
# test_result not found for image subject ID 1227, returning NONE
# test_result not found for image subject ID 1227, returning NONE
# test_result not found for image subject ID 0195, returning NONE
# test_result not found for image subject ID 0195, returning NONE
# test_result not found for image subject ID 0195, returning NONE
# test_result not found for image subject ID 0195, returning NONE
# test_result not found for image subject ID 0195, returning NONE
# test_result not found for image subject ID 0987, returning NONE
# test_result not found for image subject ID 0987, returning NONE
# test_result not found for image subject ID 0987, returning NONE
# test_result not found for image subject ID 0947, returning NONE
# test_result not found for image subject ID 0947, returning NONE
# test_result not found for image subject ID 0947, returning NONE
# test_result not found for image subject ID 0947, returning NONE
# test_result not found for image subject ID 0708, returning NONE
# test_result not found for image subject ID 0708, returning NONE
# test_result not found for image subject ID 0708, returning NONE
# test_result not found for image subject ID 0190, returning NONE
# test_result not found for image subject ID 0190, returning NONE
# test_result not found for image subject ID 0190, returning NONE
# test_result not found for image subject ID 0054, returning NONE
# test_result not found for image subject ID 0054, returning NONE
# test_result not found for image subject ID 0054, returning NONE
# test_result not found for image subject ID 1293, returning NONE
# test_result not found for image subject ID 1293, returning NONE
# test_result not found for image subject ID 1293, returning NONE
# test_result not found for image subject ID 0531, returning NONE
# test_result not found for image subject ID 0531, returning NONE
# test_result not found for image subject ID 0531, returning NONE
# test_result not found for image subject ID 0928, returning NONE
# test_result not found for image subject ID 0928, returning NONE
# test_result not found for image subject ID 0928, returning NONE
# test_result not found for image subject ID 0928, returning NONE
# test_result not found for image subject ID 0607, returning NONE
# test_result not found for image subject ID 0607, returning NONE
# test_result not found for image subject ID 0607, returning NONE
# test_result not found for image subject ID 0607, returning NONE
# test_result not found for image subject ID 1299, returning NONE
# test_result not found for image subject ID 1299, returning NONE
# test_result not found for image subject ID 1299, returning NONE
# test_result not found for image subject ID 1182, returning NONE
# test_result not found for image subject ID 1182, returning NONE
# test_result not found for image subject ID 1182, returning NONE
# test_result not found for image subject ID 0507, returning NONE
# test_result not found for image subject ID 0507, returning NONE
# test_result not found for image subject ID 0507, returning NONE
# test_result not found for image subject ID 0507, returning NONE
# test_result not found for image subject ID 0507, returning NONE
# test_result not found for image subject ID 0507, returning NONE
# test_result not found for image subject ID 0549, returning NONE
# test_result not found for image subject ID 0549, returning NONE
# test_result not found for image subject ID 0549, returning NONE
# test_result not found for image subject ID 1421, returning NONE
# test_result not found for image subject ID 1421, returning NONE
# test_result not found for image subject ID 1421, returning NONE
# test_result not found for image subject ID 1240, returning NONE
# test_result not found for image subject ID 1240, returning NONE
# test_result not found for image subject ID 1240, returning NONE
# test_result not found for image subject ID 0976, returning NONE
# test_result not found for image subject ID 0976, returning NONE
# test_result not found for image subject ID 0976, returning NONE
# test_result not found for image subject ID 0187, returning NONE
# test_result not found for image subject ID 0187, returning NONE
# test_result not found for image subject ID 0187, returning NONE
# test_result not found for image subject ID 0187, returning NONE
# test_result not found for image subject ID 0187, returning NONE
# test_result not found for image subject ID 0187, returning NONE
# test_result not found for image subject ID 1277, returning NONE
# test_result not found for image subject ID 1277, returning NONE
# test_result not found for image subject ID 1277, returning NONE
# test_result not found for image subject ID 0078, returning NONE
# test_result not found for image subject ID 0078, returning NONE
# test_result not found for image subject ID 0078, returning NONE
# test_result not found for image subject ID 0078, returning NONE
# test_result not found for image subject ID 0078, returning NONE
# test_result not found for image subject ID 0078, returning NONE
# test_result not found for image subject ID 0030, returning NONE
# test_result not found for image subject ID 0030, returning NONE
# test_result not found for image subject ID 0030, returning NONE
# test_result not found for image subject ID 0030, returning NONE
# test_result not found for image subject ID 0030, returning NONE
# test_result not found for image subject ID 0030, returning NONE
# test_result not found for image subject ID 0424, returning NONE
# test_result not found for image subject ID 0424, returning NONE
# test_result not found for image subject ID 0424, returning NONE
# test_result not found for image subject ID 1275, returning NONE
# test_result not found for image subject ID 1275, returning NONE
# test_result not found for image subject ID 1275, returning NONE
# test_result not found for image subject ID 0856, returning NONE
# test_result not found for image subject ID 0856, returning NONE
# test_result not found for image subject ID 0856, returning NONE
# test_result not found for image subject ID 0414, returning NONE
# test_result not found for image subject ID 0414, returning NONE
# test_result not found for image subject ID 0414, returning NONE
# test_result not found for image subject ID 0414, returning NONE
# test_result not found for image subject ID 0249, returning NONE
# test_result not found for image subject ID 0249, returning NONE
# test_result not found for image subject ID 0249, returning NONE
# test_result not found for image subject ID 0249, returning NONE
# test_result not found for image subject ID 0249, returning NONE
# test_result not found for image subject ID 0675, returning NONE
# test_result not found for image subject ID 0675, returning NONE
# test_result not found for image subject ID 0675, returning NONE
# test_result not found for image subject ID 1224, returning NONE
# test_result not found for image subject ID 1224, returning NONE
# test_result not found for image subject ID 1224, returning NONE
# test_result not found for image subject ID 0954, returning NONE
# test_result not found for image subject ID 0954, returning NONE
# test_result not found for image subject ID 0954, returning NONE
# test_result not found for image subject ID 0954, returning NONE
# C:\Users\bruno\AppData\Local\Temp/ipykernel_17516/1815732370.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subjects["Subject_ID"] = subjects["Subject"].apply(lambda x: x.split("_")[-1])
# C:\Users\bruno\AppData\Local\Temp/ipykernel_17516/1815732370.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subjects["Acq Date"] = pd.to_datetime(subjects["Acq Date"])
# test_result not found for image subject ID 1197, returning NONE
# test_result not found for image subject ID 1197, returning NONE
# test_result not found for image subject ID 1197, returning NONE
# test_result not found for image subject ID 1094, returning NONE
# test_result not found for image subject ID 1094, returning NONE
# test_result not found for image subject ID 1094, returning NONE
# test_result not found for image subject ID 0726, returning NONE
# test_result not found for image subject ID 0726, returning NONE
# test_result not found for image subject ID 0726, returning NONE
# test_result not found for image subject ID 0283, returning NONE
# test_result not found for image subject ID 0283, returning NONE
# test_result not found for image subject ID 0283, returning NONE
# test_result not found for image subject ID 0184, returning NONE
# test_result not found for image subject ID 0184, returning NONE
# test_result not found for image subject ID 0184, returning NONE
# test_result not found for image subject ID 0184, returning NONE
# test_result not found for image subject ID 0184, returning NONE
# test_result not found for image subject ID 0086, returning NONE
# test_result not found for image subject ID 0086, returning NONE
# test_result not found for image subject ID 0086, returning NONE
# test_result not found for image subject ID 0086, returning NONE
# test_result not found for image subject ID 0525, returning NONE
# test_result not found for image subject ID 0525, returning NONE
# test_result not found for image subject ID 0525, returning NONE
# test_result not found for image subject ID 0525, returning NONE
# test_result not found for image subject ID 0525, returning NONE
# test_result not found for image subject ID 0525, returning NONE
# test_result not found for image subject ID 0488, returning NONE
# test_result not found for image subject ID 0488, returning NONE
# test_result not found for image subject ID 0488, returning NONE
# test_result not found for image subject ID 0488, returning NONE
# test_result not found for image subject ID 0488, returning NONE
# test_result not found for image subject ID 0488, returning NONE
# test_result not found for image subject ID 0433, returning NONE
# test_result not found for image subject ID 0433, returning NONE
# test_result not found for image subject ID 0433, returning NONE
# test_result not found for image subject ID 0433, returning NONE
# test_result not found for image subject ID 0433, returning NONE
# test_result not found for image subject ID 0433, returning NONE
# test_result not found for image subject ID 1301, returning NONE
# test_result not found for image subject ID 1301, returning NONE
# test_result not found for image subject ID 1301, returning NONE
# test_result not found for image subject ID 1200, returning NONE
# test_result not found for image subject ID 1200, returning NONE
# test_result not found for image subject ID 1200, returning NONE
# ...
# test_result not found for image subject ID 1385, returning NONE
# test_result not found for image subject ID 1385, returning NONE
# test_result not found for image subject ID 1385, returning NONE
# test_result not found for image subject ID 1254, returning NONE
# test_result not found for image subject ID 1254, returning NONE
# test_result not found for image subject ID 1254, returning NONE
# test_result not found for image subject ID 1082, returning NONE
# test_result not found for image subject ID 1082, returning NONE
# test_result not found for image subject ID 1082, returning NONE
# test_result not found for image subject ID 0850, returning NONE
# test_result not found for image subject ID 0850, returning NONE
# test_result not found for image subject ID 0850, returning NONE
# test_result not found for image subject ID 0404, returning NONE
# test_result not found for image subject ID 0404, returning NONE
# test_result not found for image subject ID 0404, returning NONE
# test_result not found for image subject ID 1307, returning NONE
# test_result not found for image subject ID 1307, returning NONE
# test_result not found for image subject ID 1307, returning NONE
# test_result not found for image subject ID 1171, returning NONE
# test_result not found for image subject ID 1171, returning NONE
# test_result not found for image subject ID 1171, returning NONE
# test_result not found for image subject ID 1262, returning NONE
# test_result not found for image subject ID 1262, returning NONE
# test_result not found for image subject ID 1262, returning NONE
# test_result not found for image subject ID 1262, returning NONE
# test_result not found for image subject ID 0916, returning NONE
# test_result not found for image subject ID 0916, returning NONE
# test_result not found for image subject ID 0916, returning NONE
# test_result not found for image subject ID 0916, returning NONE
# test_result not found for image subject ID 0916, returning NONE
# test_result not found for image subject ID 0084, returning NONE
# test_result not found for image subject ID 0084, returning NONE
# test_result not found for image subject ID 0053, returning NONE
# test_result not found for image subject ID 0053, returning NONE
# test_result not found for image subject ID 0053, returning NONE
# test_result not found for image subject ID 0010, returning NONE
# test_result not found for image subject ID 0010, returning NONE
# test_result not found for image subject ID 0010, returning NONE
# test_result not found for image subject ID 0786, returning NONE
# test_result not found for image subject ID 0786, returning NONE
# test_result not found for image subject ID 0786, returning NONE
# test_result not found for image subject ID 0786, returning NONE
# test_result not found for image subject ID 0316, returning NONE
# test_result not found for image subject ID 0316, returning NONE
# test_result not found for image subject ID 0316, returning NONE
# test_result not found for image subject ID 0316, returning NONE
# test_result not found for image subject ID 0547, returning NONE
# test_result not found for image subject ID 0547, returning NONE
# test_result not found for image subject ID 0547, returning NONE
# test_result not found for image subject ID 0814, returning NONE
# test_result not found for image subject ID 0814, returning NONE
# test_result not found for image subject ID 0814, returning NONE
# test_result not found for image subject ID 0221, returning NONE
# test_result not found for image subject ID 0221, returning NONE
# test_result not found for image subject ID 0221, returning NONE
# test_result not found for image subject ID 0938, returning NONE
# test_result not found for image subject ID 0938, returning NONE
# test_result not found for image subject ID 0938, returning NONE
# test_result not found for image subject ID 0938, returning NONE
# test_result not found for image subject ID 0816, returning NONE
# test_result not found for image subject ID 0816, returning NONE
# test_result not found for image subject ID 0816, returning NONE
# test_result not found for image subject ID 0816, returning NONE
# test_result not found for image subject ID 0619, returning NONE
# test_result not found for image subject ID 0619, returning NONE
# test_result not found for image subject ID 0619, returning NONE
# test_result not found for image subject ID 0619, returning NONE
# C:\Users\bruno\AppData\Local\Temp/ipykernel_17516/1815732370.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subjects["Subject_ID"] = subjects["Subject"].apply(lambda x: x.split("_")[-1])
# C:\Users\bruno\AppData\Local\Temp/ipykernel_17516/1815732370.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subjects["Acq Date"] = pd.to_datetime(subjects["Acq Date"])
# test_result not found for image subject ID 0696, returning NONE
# test_result not found for image subject ID 0696, returning NONE
# test_result not found for image subject ID 0696, returning NONE
# test_result not found for image subject ID 0497, returning NONE
# test_result not found for image subject ID 0497, returning NONE
# test_result not found for image subject ID 0497, returning NONE
# test_result not found for image subject ID 1290, returning NONE
# test_result not found for image subject ID 1290, returning NONE
# test_result not found for image subject ID 1290, returning NONE
# test_result not found for image subject ID 1221, returning NONE
# test_result not found for image subject ID 1221, returning NONE
# test_result not found for image subject ID 1221, returning NONE
# test_result not found for image subject ID 0891, returning NONE
# test_result not found for image subject ID 0891, returning NONE
# test_result not found for image subject ID 0891, returning NONE
# test_result not found for image subject ID 0784, returning NONE
# test_result not found for image subject ID 0784, returning NONE
# test_result not found for image subject ID 0784, returning NONE
# test_result not found for image subject ID 0091, returning NONE
# test_result not found for image subject ID 0091, returning NONE
# test_result not found for image subject ID 0091, returning NONE
# test_result not found for image subject ID 0091, returning NONE
# test_result not found for image subject ID 0091, returning NONE
# test_result not found for image subject ID 0091, returning NONE
# test_result not found for image subject ID 0392, returning NONE
# test_result not found for image subject ID 0392, returning NONE
# test_result not found for image subject ID 0392, returning NONE
# test_result not found for image subject ID 0374, returning NONE
# test_result not found for image subject ID 0374, returning NONE
